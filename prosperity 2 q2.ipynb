# %% [markdown]
# ![image.png](attachment:5d0f31f5-5f22-476f-b339-4ab689e2b29f.png)![image.png](attachment:aea3806e-0aff-4384-9dbb-d5dfaed86e73.png)

# %% [markdown]
# ![image.png](attachment:294f57ce-85fa-4382-9e19-f81950265485.png)

# %%
import numpy as np

rates = np.array([[1,0.48,1.52,0.71],[2.05,1,3.26,1.56],[0.64,0.3,1,0.46],[1.41,0.61,2.08,1]])

products = {'pizza':0,'wasabi':1,'snowball':2,'shells':3}

# %%
def firstTrades():
    return rates[products['shells']]

def secondTrades(first):
    for

# %%
def possible_firstTrade():
    possible1 = rates[3]
    return possible1

def possible_secondTrade(possibleFirstTrades):
    allPossibleSecondTrades = []
    for i in range(0,4):
        l1 = []
        l1.append(possibleFirstTrades[i])
        secondTrades = rates[i]
        for j in secondTrades:
            l1.append(j)
            allPossibleSecondTrades.append(l1)
            l1 = [possibleFirstTrades[i]]
    return allPossibleSecondTrades

# %%
print(possible_secondTrade(possible_firstTrade()))
# Out:
# [[np.float64(1.41), np.float64(1.0)], [np.float64(1.41), np.float64(0.48)], [np.float64(1.41), np.float64(1.52)], [np.float64(1.41), np.float64(0.71)], [np.float64(0.61), np.float64(2.05)], [np.float64(0.61), np.float64(1.0)], [np.float64(0.61), np.float64(3.26)], [np.float64(0.61), np.float64(1.56)], [np.float64(2.08), np.float64(0.64)], [np.float64(2.08), np.float64(0.3)], [np.float64(2.08), np.float64(1.0)], [np.float64(2.08), np.float64(0.46)], [np.float64(1.0), np.float64(1.41)], [np.float64(1.0), np.float64(0.61)], [np.float64(1.0), np.float64(2.08)], [np.float64(1.0), np.float64(1.0)]]
