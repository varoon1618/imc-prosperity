# %%
import pandas as pd

# %%
df = pd.read_csv(r'./data/round1/prices_round_1_day_-2.csv',sep=';')

# %%
df.head()
# Out:
#    day  timestamp           product  bid_price_1  bid_volume_1  bid_price_2  \
# 0   -2          0  RAINFOREST_RESIN         9996             1       9995.0
# 1   -2          0              KELP         1998            26          NaN
# 2   -2          0         SQUID_INK         1998            26          NaN
# 3   -2        100         SQUID_INK         1999             5       1998.0
# 4   -2        100  RAINFOREST_RESIN        10000             5       9995.0
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0          25.0          NaN           NaN        10004             1
# 1           NaN          NaN           NaN         2002            26
# 2           NaN          NaN           NaN         2002            26
# 3          26.0          NaN           NaN         2001            20
# 4          20.0          NaN           NaN        10005            20
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
squid = df[df['product'] == 'SQUID_INK']['mid_price']

# %%
kelp = df[df['product'] == 'KELP']['mid_price']
resin = df[df['product'] == 'RAINFOREST_RESIN']['mid_price']

# %%
plt.plot(kelp,squid)
plt.xlabel('kelp price')
plt.ylabel('squid price')
plt.show()

# %%
x = range(len(squid))  # or any other list of same length
x2 = range(len(kelp))
plt.plot(x, squid,label='squid',color='red')
plt.plot(x2,kelp,label='kelp',color='blue')
plt.show()

# %%
squid_df = df[df['product'] == 'SQUID_INK']
squid_df = squid_df.fillna(0)

# %%
ask1 = squid_df['ask_volume_1']
ask2 = squid_df['ask_volume_2']
ask3 = squid_df['ask_volume_3']
totalAsk = squid_df['ask_volume_1']+ squid_df['ask_volume_2']+squid_df['ask_volume_3']

bid1 = squid_df['bid_volume_1']
bid2 = squid_df['bid_volume_2']
bid3 = squid_df['bid_volume_3']
totalBid = squid_df['bid_volume_1']+ squid_df['bid_volume_2']+squid_df['bid_volume_3']

# %%
plt.plot(range(len(totalAsk)),totalAsk,label='total ask',color='red')
plt.plot(range(len(totalBid)),totalBid,label = 'total bid',color='blue')

plt.show()

# %%
plt.plot(totalAsk,totalBid)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
squid_df =
